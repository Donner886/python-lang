# %%
from abc import ABCMeta

# %%
class MyInterface(metaclass=ABCMeta):
    pass

# %%
MyInterface.register()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 MyInterface.register()
#
# TypeError: ABCMeta.register() missing 1 required positional argument: 'subclass'

# %%
import sys
sys.builtin_module_names
# Out:
# ('_abc',
#  '_ast',
#  '_bisect',
#  '_blake2',
#  '_codecs',
#  '_codecs_cn',
#  '_codecs_hk',
#  '_codecs_iso2022',
#  '_codecs_jp',
#  '_codecs_kr',
#  '_codecs_tw',
#  '_collections',
#  '_contextvars',
#  '_csv',
#  '_datetime',
#  '_functools',
#  '_heapq',
#  '_imp',
#  '_io',
#  '_json',
#  '_locale',
#  '_lsprof',
#  '_md5',
#  '_multibytecodec',
#  '_opcode',
#  '_operator',
#  '_pickle',
#  '_random',
#  '_sha1',
#  '_sha256',
#  '_sha3',
#  '_sha512',
#  '_signal',
#  '_sre',
#  '_stat',
#  '_statistics',
#  '_string',
#  '_struct',
#  '_symtable',
#  '_thread',
#  '_tokenize',
#  '_tracemalloc',
#  '_typing',
#  '_warnings',
#  '_weakref',
#  '_winapi',
#  '_xxsubinterpreters',
#  'array',
#  'atexit',
#  'audioop',
#  'binascii',
#  'builtins',
#  'cmath',
#  'errno',
#  'faulthandler',
#  'gc',
#  'itertools',
#  'marshal',
#  'math',
#  'mmap',
#  'msvcrt',
#  'nt',
#  'sys',
#  'time',
#  'winreg',
#  'xxsubtype',
#  'zlib')

# %% [markdown]
# ### ABCMeta的例子

# %%
class Foo:
    def __getitem__(self, item):
        pass
    
    def __len__(self):
        pass
    
    def get_iterator(self):
        return iter(self)

# %%
class MyIterable(metaclass=ABCMeta):
